# %%
import  json
import requests

# %%
resp=requests.get('https://www.courtlistener.com/api/rest/v3/dockets')

# %%
resp.text
# Out:
# '{"count":59676947,"next":"https://www.courtlistener.com/api/rest/v3/dockets/?page=2","previous":null,"results":[{"resource_uri":"https://www.courtlistener.com/api/rest/v3/dockets/61148830/","id":61148830,"court":"https://www.courtlistener.com/api/rest/v3/courts/txsd/","original_court_info":null,"idb_data":null,"clusters":[],"audio_files":[],"assigned_to":null,"referred_to":null,"absolute_url":"/docket/61148830/united-states-v-sanchez-quiroz/","date_created":"2021-11-13T15:33:02.260727-08:00","date_modified":"2021-11-13T15:33:02.306224-08:00","source":1,"appeal_from_str":"","assigned_to_str":"","referred_to_str":"","panel_str":"","date_last_index":"2021-11-13T15:33:02.306233-08:00","date_cert_granted":null,"date_cert_denied":null,"date_argued":null,"date_reargued":null,"date_reargument_denied":null,"date_filed":"2010-10-31","date_terminated":"2010-10-31","date_last_filing":"2010-11-01","case_name_short":"","case_name":"United States v. Sanchez Quiroz","case_name_full":"","slug":"unit
# ...
