# %%
import os, shutil

# %%
os.listdir('archive/Training Data')
# Out:
# ['Anime', 'Cartoon']

# %%
anime_set='archive/Training Data/Anime'
cartoon_set='archive/Training Data/Cartoon'

# %%
os.listdir('archive/Training Data/Anime')
# Out:
# ['Ace of Diamond',
#  'Akame ga Kill!',
#  'Angel Beats',
#  'Anohana The Flower We Saw That Day',
#  'Attack on Titan',
#  'Baccano',
#  'Black Butler',
#  'Black Cat',
#  'Black Lagoon',
#  'Bleach',
#  'Btooom',
#  'Chobits',
#  'Code Geass',
#  'Cowboy Bebop',
#  'Darker Than Black',
#  'Deadman Wonderland',
#  'Death Note',
#  'Demon Slayer',
#  'Dragon ball',
#  'Dragon Ball Z Kai',
#  'Ergo Proxy',
#  'Eureka Seven',
#  'Fairy Tail',
#  'Fighting Spirit',
#  'Food Wars',
#  'Fullmetal Alchemist Brotherhood',
#  'Future Diary',
#  'Gekijouban FateStay Night Unlimited Blade Works',
#  'Get Backers',
#  'Haikyuu',
#  'Hunter x Hunter',
#  'Kuroko Basketball',
#  'Magi The labyrinth of magic',
#  'Monster',
#  'Naruto',
#  'Naruto Shippuden',
#  'Neon Genesis Evangelion',
#  'No Game, No Life',
#  'One Outs',
#  'One Piece',
#  'one punch man',
#  'Paranoia Agent',
#  'Parasyte The Maxim',
#  'Phantom Requiem for the Phantom',
#  'Psycho Pass',
#  'Puella Magi Madoka Magica',
# ...

# %%
imgs_anime=[]

for item in os.listdir('archive/Training Data/Anime'):
    loca=os.listdir('archive/Training Data/Anime'+'/'+item)
    for item2 in loca:
        imgs = [file for file in os.listdir('archive/Training Data/Anime'+'/'+item) if file.endswith('.jpg')]
        imgs_anime.append(imgs)

# %%
type(imgs_anime[1000])
# Out:
# list

# %%
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...
